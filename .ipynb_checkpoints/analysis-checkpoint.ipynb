# %%
import pandas as pd 
pd.options.mode.chained_assignment = None
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt
import matplotlib
from multiprocessing import Pool
# from profilestats import profile
from scipy.stats import binned_statistic
from funcs.analysis import *
# %matplotlib inline

def reader(n_subarray):
    return pd.read_csv('data/merged/{}/lc_{}.csv'.format(obj, n_subarray), nrows=1000, index_col = ID, dtype = {'catalogue': np.uint8, 'mag_ps': np.float32, 'magerr': np.float32, 'mjd': np.float64, ID: np.uint32})

# %%
obj = 'qsos'
ID  = 'uid'

# Here we load the analysis class. This has various attibutes and methods outlined in /funcs/analysis.py
# Examples:
# Photometry is in dr.df
# Grouped statistics is in dr.grouped
# DR12 VAC properties are in dr.properties
dr = analysis(obj, ID)

# %%
dr.read_in(reader, redshift=False)
# dr.group(keys = ['uid'],read_in=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-2f827327606f> in <module>
# ----> 1 dr.read_in(redshift=False)
#       2 # dr.group(keys = ['uid'],read_in=True)
#
# /disk1/hrb/quirky_quasars/funcs/analysis.py in read_in(self, multi_proc, catalogue_of_properties, redshift)
#      41                 # Default to 4 cores
#      42                 pool = Pool(4)
# ---> 43                 df_list = pool.map(reader, range(4))
#      44                 self.df = pd.concat(df_list).rename(columns={'mag_ps':'mag'})
#      45
#
# /disk1/hrb/anaconda3/envs/astroconda/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /disk1/hrb/anaconda3/envs/astroconda/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# /disk1/hrb/anaconda3/envs/astroconda/lib/python3.6/multiprocessing/pool.py in _handle_tasks(taskqueue, put, outqueue, pool, cache)
#     422                         break
#     423                     try:
# --> 424                         put(task)
#     425                     except Exception as e:
#     426                         job, idx = task[:2]
#
# /disk1/hrb/anaconda3/envs/astroconda/lib/python3.6/multiprocessing/connection.py in send(self, obj)
#     204         self._check_closed()
#     205         self._check_writable()
# --> 206         self._send_bytes(_ForkingPickler.dumps(obj))
#     207
#     208     def recv_bytes(self, maxlength=None):
#
# /disk1/hrb/anaconda3/envs/astroconda/lib/python3.6/multiprocessing/reduction.py in dumps(cls, obj, protocol)
#      49     def dumps(cls, obj, protocol=None):
#      50         buf = io.BytesIO()
# ---> 51         cls(buf, protocol).dump(obj)
#      52         return buf.getbuffer()
#      53
#
# AttributeError: Can't pickle local object 'analysis.read_in.<locals>.reader'

# %% [markdown]
# ### Example: finding qsos given ra, dec

# %% [markdown]
# > Define a list of ra and decs in the format below

# %%
ra_dec = [[0.00531, -2.0332],[359.999615, 3.268586], [359.99851, -0.65588]]

# %%
found = dr.search(ra_dec, 1)
print(len(found))
found
# Out:
# 3
#                 ra       dec  dist_arcsec
# uid
# 6         0.005317 -2.033273     0.265037
# 526347  359.998520 -0.655884     0.001054
# 526354  359.999615  3.268586     0.039144

# %%
dr.plt_color
# Out:
# {'u': 'm', 'g': 'g', 'r': 'r', 'i': 'k', 'z': 'b'}

# %% [markdown]
# ### Load DR12 VAC catalogue

# %%
dr.merge_with_catalogue(catalogue='dr12_vac', remove_outliers=True, prop_range_any = {'MBH_MgII':(6,12), 'MBH_CIV':(6,12)})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-87634011f7c3> in <module>
# ----> 1 dr.merge_with_catalogue(catalogue='dr12_vac', remove_outliers=True, prop_range_any = {'MBH_MgII':(6,12), 'MBH_CIV':(6,12)})
#
# /disk1/hrb/quirky_quasars/funcs/analysis.py in merge_with_catalogue(self, catalogue, remove_outliers, prop_range_any)
#     183
#     184                 # Recalculate which qsos we are missing and which we have, given a list (copy of code in self.summary)
# --> 185                 self.summary()
#     186
#     187 #                          self.properties = self.df_grouped.reset_index('catalogue').join(vac, how = 'inner', on=self.ID)
#
# /disk1/hrb/quirky_quasars/funcs/analysis.py in summary(self)
#      79                 self.idx_cat      = self.df['catalogue'].unique()
#      80
# ---> 81                 print('Number of qsos with lightcurves in {} band : {:,}'.format(self.band, self.n_qsos))
#      82 		print('Number of datapoints in:\nSDSS: {:,}\nPS: {:,}\nZTF: {:,}'.format((self.df['catalogue']==1).sum(),
#      83                                                                                                                                                                                                                                                                                                                  (self.df['catalogue']==2).sum(),
#
# AttributeError: 'analysis' object has no attribute 'band'

# %% [markdown]
# > Columns included in the value added catalogue:

# %%
list(dr.properties.columns)

# %%
dr.properties

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1766">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# > Example: plot photometry of quasars with uid: [6, 526352, 526344] (currently only r band)

# %%
dr.plot_series_bokeh(bg_uids)
# Out:
#   <div class="bk-root" id="045885b2-8d16-42f1-82ae-870734376923" data-root-id="3591"></div>
